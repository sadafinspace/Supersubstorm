# %%
import pyspedas
import pytplot
from pytplot import tplot, options, tlimit, tplot_names
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.colors import ListedColormap
from mpl_toolkits.axes_grid1 import make_axes_locatable
import os
import datetime
import netCDF4
from netCDF4 import Dataset, num2date
import datetime as dt
from pytplot import get_data
import csv
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt
from dateutil.parser import isoparse as isotoutc
import arrow

# %%
filename = "/Users/sians/OneDrive/Desktop/LANL_2015/Data file/20150907_LANL-97A_10sec_flux.txt"

from dateutil.parser import isoparse as isotoutc

# Open the file in read mode
with open(filename, "r") as file:
    # Read the first 130 lines into a string array
    lanl_header = []
    for i in range(130):
        line = file.readline()
        lanl_header.append(line.strip())

    # Read the remaining data into a floating-point array
    data_array = []
    for line in file:
        values = line.strip().split()  # Split the line into individual values

        # Convert the ISO timestamp in the first column to Unix timestamp
        iso_timestamp = values[0]
      
        dt=arrow.get(iso_timestamp).datetime
        #print(dt.timestamp())
        
        # Replace the ISO timestamp with the Unix timestamp in the first column
        values[0] = dt.timestamp()

        # Convert the remaining values to float
        float_values = [float(x) for x in values[1:]]
        
        # Add the Unix timestamp and the float values to the float array
        data_array.append([dt] + float_values)

# %%
# Extract the first column
time = [row[0] for row in data_array] # first coulmn
# print(timefrac)
lat = [row[1] for row in data_array] #second column
long = [row[3] for row in data_array] #third column
radius = [row[4] for row in data_array] #fourth column
sopa_elec_flux= [row[5:15] for row in data_array] #5th to 14 coulmn-
# esp_elec_flux= [row[26:36] for row in data_array] #27 to end coulmn-
# sopa_elec_energy= [row[15:24] for row in data_array]
sopa_ion_flux= [row[15:22] for row in data_array] #15th to 26 coulmn-


# energyEflux1=[1122.5,1989.98,2437.21,3074.09,3968.63,5196.15,6841.05,9178.24,16692.5]

#converting time to datetime
time_new=[]
for i in range(0,len(time)):
    time_new= np.append(time_new, time[i])

# %%
# dat = {'x': time_new, 'y': sopa_elec_flux, 'v': energyEflux1}
# store_data('Eflux1', dat)

# %%
time
# Out:
# [datetime.datetime(2015, 9, 7, 0, 2, 2, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 2, 12, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 2, 22, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 2, 32, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 2, 42, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 2, 52, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 3, 2, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 3, 12, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 3, 22, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 3, 32, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 3, 42, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 3, 52, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 4, 2, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 4, 12, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 4, 22, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 4, 32, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 4, 42, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 4, 52, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 5, 2, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 5, 12, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 5, 22, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 5, 32, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 5, 42, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 5, 52, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 6, 2, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 6, 12, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 6, 22, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 6, 32, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 6, 42, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 6, 52, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 7, 2, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 7, 12, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 7, 22, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 7, 32, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 7, 42, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 7, 52, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 8, 2, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 8, 12, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 8, 22, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 8, 32, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 8, 42, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 8, 52, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 9, 2, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 9, 12, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 9, 22, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 9, 32, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 9, 42, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 9, 52, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 10, 2, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 10, 12, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 10, 22, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 10, 32, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 10, 42, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 10, 52, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 11, 2, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 11, 12, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 11, 22, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 11, 32, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 11, 42, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 11, 52, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 12, 2, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 12, 12, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 12, 22, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 12, 32, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 12, 42, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 12, 52, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 13, 2, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 13, 12, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 13, 22, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 13, 32, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 13, 42, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 13, 52, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 14, 2, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 14, 12, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 14, 22, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 14, 32, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 14, 42, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 14, 52, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 15, 2, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 15, 12, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 15, 22, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 15, 32, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 15, 42, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 15, 52, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 16, 2, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 16, 12, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 16, 22, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 16, 32, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 16, 42, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 16, 52, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 17, 2, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 17, 12, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 17, 22, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 17, 32, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 17, 42, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 17, 52, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 18, 2, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 18, 12, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 18, 22, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 18, 32, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 18, 42, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 18, 52, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 19, 2, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 19, 12, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 19, 22, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 19, 32, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 19, 42, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 19, 52, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 20, 2, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 20, 12, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 20, 22, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 20, 32, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 20, 42, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 20, 52, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 21, 2, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 21, 12, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 21, 22, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 21, 32, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 21, 42, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 21, 52, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 22, 2, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 22, 12, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 0, 22,
 52, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 30, 2, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 30, 12, 424000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 30, 22, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 30, 32, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 30, 42, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 30, 52, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 31, 2, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 31, 12, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 31, 22, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 31, 32, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 31, 42, 424000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 31, 52, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 32, 2, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 32, 12, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 32, 22, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 32, 32, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 32, 42, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 32, 52, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 33, 2, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 33, 12, 424000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 33, 22, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 33, 32, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 33, 42, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 33, 52, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 34, 2, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 34, 12, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 34, 22, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 34, 32, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 34, 42, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 34, 52, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 35, 2, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 35, 12, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 35, 22, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 35, 32, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 35, 42, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 35, 52, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 36, 2, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 36, 12, 424000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 36, 22, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 36, 32, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 36, 42, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 36, 52, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 37, 2, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 37, 12, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 37, 22, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 37, 32, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 37, 42, 424000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 37, 52, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 38, 2, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 38, 12, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 38, 22, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 38, 32, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 38, 42, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 38, 52, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 39, 2, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 39, 12, 424000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 39, 22, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 39, 32, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 39, 42, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 39, 52, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 40, 2, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 40, 12, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 40, 22, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 40, 32, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 40, 42, 424000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 40, 52, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 41, 2, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 41, 12, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 41, 22, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 41, 32, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 41, 42, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 41, 52, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 42, 2, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 42, 12, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 42, 22, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 42, 32, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 42, 42, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 42, 52, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 43, 2, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 43, 12, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 43, 22, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 43, 32, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 43, 42, 424000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 43, 52, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 44, 2, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 44, 12, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 44, 22, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 44, 32, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 44, 42, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 44, 52, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 45, 2, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 45, 12, 424000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 45, 22, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 45, 32, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 45, 42, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 45, 52, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 46, 2, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 46, 12, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 46, 22, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 46, 32, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 46, 42, 424000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 46, 52, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 47, 2, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 47, 12, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 47, 22, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 47, 32, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 47, 42, 421000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 47, 52, 422000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 48, 2, 423000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 48, 12, 424000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 48, 22, 420000, tzinfo=tzutc()),
#  datetime.datetime(2015, 9, 7, 2, 48, 32, 421000, tzinfo=tzutc()),
#  ...]

# %%
# Plots
# Create a plot with a single y-axis
import datetime as dt
fig, ax1 = plt.subplots(figsize=(10, 16))
ax1.semilogy(time_new, sopa_elec_flux)
# set limits on the x-axis
ax1.set_xlim(dt.datetime(2015, 9, 7, 12, 0, 0), dt.datetime(2015, 9, 7, 19, 0, 0))

line_date = dt.datetime(2015, 9, 7, 14, 12, 0)
# draw a vertical line at the line date
ax1.axvline(x=line_date, color='r')

####################################################
# line_date1 = dt.datetime(2015, 9, 7, 15, 20, 0)
# line_date2 = dt.datetime(2015, 9, 7, 15, 45, 0)

# ax1.axvline(x=line_date1, color='magenta')
# ax1.axvline(x=line_date2, color='magenta')
#####################################################

# ax1.set_xlim(start_date, end_date)
ax1.set_ylim([0, 1e7])
# ax1.axvline(x= line_date, color='r')

ax1.set_xlabel('Time (UTC)', fontsize=16)
ax1.set_ylabel('SOPA-Electron Flux', fontsize=16) #($cm^{-2}$$s^{-1}$$sr^{-1}$$eV^{-1}$)')
ax1.set_title('LANL-097A', fontsize=16)

##[61.2373,88.7412,125.499,183.712,266.224,396.863,612.372,908.295,1284.52,1936.49]

ax1.plot(time_new,  sopa_elec_flux, label=['61 KeV', '88 KeV', '125 KeV', '183 KeV', '266 KeV', '396 KeV', '612 KeV', '908 KeV', '1284 KeV', '1936 KeV'])

# Add a legend outside the plot
plt.legend(loc='upper left', bbox_to_anchor=(0.84, 1))

# plt.subplots_adjust(wspace=0.5, hspace=1)

# Show the plot
plt.show()

# Add a legend to the plot
ax1.legend()
# Out:
# 14-Jun-23 20:34:47: C:\Users\sians\AppData\Local\Temp\ipykernel_6060\912164029.py:22: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim([0, 1e7])

# %%
# Plots
# Create a plot with a single y-axis
import datetime as dt
fig, ax2 = plt.subplots(figsize=(10, 16))
ax2.semilogy(time_new, sopa_ion_flux)
# set limits on the x-axis
ax2.set_xlim(dt.datetime(2015, 9, 7, 12, 0, 0), dt.datetime(2015, 9, 7, 19, 0, 0))
ax2.set_ylim([0, 1e6])

line_date = dt.datetime(2015, 9, 7, 14, 30, 0)
# draw a vertical line at the line date
ax2.axvline(x=line_date, color='r')


####################################################
# line_date1 = dt.datetime(2015, 9, 7, 15, 20, 0)
# line_date2 = dt.datetime(2015, 9, 7, 15, 45, 0)

# ax1.axvline(x=line_date1, color='magenta')
# ax1.axvline(x=line_date2, color='magenta')
#####################################################

# ax1.set_xlim(start_date, end_date)

# ax1.axvline(x= line_date, color='r')

ax2.set_xlabel('Time (UTC)', fontsize=16)
ax2.set_ylabel('SOPA-Electron Flux', fontsize=16) #($cm^{-2}$$s^{-1}$$sr^{-1}$$eV^{-1}$)')
ax2.set_title('LANL-04A', fontsize=16)

##[61.2373,88.7412,125.499,183.712,266.224,396.863,612.372,908.295,1284.52,1936.49]

ax2.plot(time_new,  sopa_ion_flux, label=['61.2373','92.0598','138.6','206.155','316.228','517.687','896.661'])

# ax1.legend(loc='upper right')

# Add a legend outside the plot
plt.legend(loc='upper left', bbox_to_anchor=(0.84, 1))

# Show the plot
plt.show()
# Add a legend to the plot
ax2.legend()
# Out:
# 14-Jun-23 20:34:53: C:\Users\sians\AppData\Local\Temp\ipykernel_6060\2271852335.py:8: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax2.set_ylim([0, 1e6])

# %%
import matplotlib.pyplot as plt
import numpy as np

# Constants
earth_radius = 6371  # km

satellite_latitudes_deg = lat[:]  # List of satellite latitudes in degrees
satellite_longitudes_deg = long[:]  # List of satellite longitudes in degrees
satellite_radii = 6.619  # List of satellite radii from the Earth's center in earth radius


# Convert latitudes and longitudes from degrees to radians
satellite_latitudes_rad = np.deg2rad(satellite_latitudes_deg)
satellite_longitudes_rad = np.deg2rad(satellite_longitudes_deg)

# Calculate the Cartesian coordinates of the satellites in Earth radius units
x = 6 * np.cos(satellite_longitudes_rad) * np.cos(satellite_latitudes_rad)
y = 6 * np.sin(satellite_longitudes_rad) * np.cos(satellite_latitudes_rad)

# Create a 2D plot
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

# Plot the circle with a radius of 6.6 Earth radii
circle = plt.Circle((0, 0), 6.6, color='green', fill=False, label='Circle (6.6 Earth Radii)')
ax.add_patch(circle)

# Plot the satellite positions
plt.plot(x, y, 'ro', label='Satellites')

# Plot the Earth
plt.scatter(0, 0, color='blue', label='Earth')

# Set plot limits
plt.xlim(-7, 7)
plt.ylim(-7, 7)

# Set plot labels and title
plt.xlabel('X (Earth Radii)')
plt.ylabel('Y (Earth Radii)')
plt.title('Satellite Positions')

# Move the x and y axes to the center
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Hide the ticks
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_tick_params(width=0)
ax.yaxis.set_tick_params(width=0)

# Add legend
plt.legend()

# Show the plot
plt.show()
