# %%
import pyspedas
import pytplot
from pytplot import tplot, options, tlimit, tplot_names
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.colors import ListedColormap
from mpl_toolkits.axes_grid1 import make_axes_locatable
import os
import datetime
import netCDF4
from netCDF4 import Dataset, num2date
import datetime as dt
from pytplot import get_data

# %%
pyspedas.hapi.hapi.hapi(trange=['2015-09-07', '2015-09-08'], 
                        server='https://cdaweb.gsfc.nasa.gov/hapi', 
                        catalog=True)
# Out:
# Available datasets:
# A1_K0_MPA
# A2_K0_MPA
# AC_AT_DEF
# AC_H0_MFI
# AC_H0_SWE
# AC_H1_EPM
# AC_H1_MFI
# AC_H1_SIS
# AC_H2_CRIS
# AC_H2_EPM
# AC_H2_MFI
# AC_H2_SEP
# AC_H2_SIS
# AC_H2_SWE
# AC_H2_SWI
# AC_H2_ULE
# AC_H3_CRIS
# AC_H3_EPM
# AC_H3_MFI
# AC_H3_SW2
# AC_H3_SWI
# AC_H4_SWI
# AC_H5_SWI
# AC_H6_SWI
# AC_K0_EPM
# AC_K0_MFI
# AC_K0_SIS
# AC_K0_SWE
# AC_K1_EPM
# AC_K1_MFI
# AC_K1_SWE
# AC_K2_MFI
# AC_OR_DEF
# AC_OR_SSC
# AEROCUBE-6-A_DOSIMETER_L2
# AEROCUBE-6-B_DOSIMETER_L2
# ALOUETTE2_AV_LIM
# ALOUETTE2_AV_SNT
# ALOUETTE2_AV_SOL
# ALOUETTE2_AV_ULA
# ALOUETTE2_AV_WNK
# ALOUETTE2_NEPROF_TOPS
# AMPTECCE_H0_MEPA@0
# AMPTECCE_H0_MEPA@1
# AMPTECCE_H0_MEPA@2
# AMPTECCE_H0_MEPA@3
# AMPTECCE_H0_MEPA@4
# BAR_1A_L2_EPHM
# BAR_1A_L2_FSPC
# BAR_1A_L2_HKPG
# BAR_1A_L2_MAGN
# BAR_1A_L2_MSPC
# BAR_1A_L2_RCNT
# BAR_1A_L2_SSPC
# BAR_1B_L2_EPHM
# BAR_1B_L2_FSPC
# BAR_1B_L2_HKPG
# BAR_1B_L2_MAGN
# BAR_1B_L2_MSPC
# BAR_1B_L2_RCNT
# BAR_1B_L2_SSPC
# BAR_1C_L2_EPHM
# BAR_1C_L2_FSPC
# ...

# %%
opts = {'trange': ['2015-09-07', '2015-09-08'],
        'server': 'https://cdaweb.gsfc.nasa.gov/hapi'}

# %%
pyspedas.hapi.hapi.hapi(**opts, dataset='C1_PP_RAP')
data_c1_lo = get_data('J_e_lo__C1_PP_RAP')
data_c1_hi = get_data('J_e_hi__C1_PP_RAP')

# %%
pyspedas.hapi.hapi.hapi(**opts, dataset='C2_PP_RAP')
data_c2_lo = get_data('J_e_lo__C2_PP_RAP')
data_c2_hi = get_data('J_e_hi__C2_PP_RAP')

# %%
pyspedas.hapi.hapi.hapi(**opts, dataset='C3_PP_RAP')
data_c3_lo = get_data('J_e_lo__C3_PP_RAP')
data_c3_hi = get_data('J_e_hi__C3_PP_RAP')

# %%
pyspedas.hapi.hapi.hapi(**opts, dataset='C4_PP_RAP')
data_c4_lo = get_data('J_e_lo__C4_PP_RAP')
data_c4_hi = get_data('J_e_hi__C4_PP_RAP')

# %%
metadata = get_data('J_e_lo__C3_PP_RAP', metadata=True)

# %%
metadata['HAPI']
# Out:
# {'name': 'J_e_lo__C3_PP_RAP',
#  'type': 'double',
#  'units': '1/(cm^2 s sr)',
#  'fill': '-1.0E31',
#  'description': 'Electron Flux (E>30 kev), Integral flux averaged over 4 pi'}

# %%
tlimit(['2015-09-07 12:00:00', '2015-09-07 19:00:00'])
# options('J_e_lo__C1_PP_RAP', 'spec', True)
options('J_e_lo__C1_PP_RAP', 'ylog', True)
options('J_e_hi__C1_PP_RAP', 'ylog', True)
options('J_e_lo__C1_PP_RAP', 'spec', True)
options('J_e_hi__C1_PP_RAP', 'spec', True)

pytplot.timebar(1441642020.0, thick=2, color='red')
tplot(['J_e_lo__C1_PP_RAP', 'J_e_hi__C1_PP_RAP' ])
# pytplot.tplot("J_e_lo__C1_PP_RAP.8MeV_a", var_label = ["L", "MLT" ])
# Out:
# J_e_lo__C1_PP_RAP does not contain coordinates for spectrogram plotting.  Continuing...
# J_e_hi__C1_PP_RAP does not contain coordinates for spectrogram plotting.  Continuing...
# 14-Jun-23 03:25:47: C:\Users\sians\anaconda3\lib\site-packages\pytplot\MPLPlotter\tplot.py:238: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   this_axis.set_ylim(yrange)

# %%
options('J_e_lo__C2_PP_RAP', 'ylog', True)
options('J_e_hi__C2_PP_RAP', 'ylog', True)
pytplot.timebar(1441642020.0, thick=2, color='red')
tplot(['J_e_lo__C2_PP_RAP', 'J_e_hi__C2_PP_RAP' ])
# Out:
# 11-Jun-23 20:38:12: C:\Users\sians\anaconda3\lib\site-packages\pytplot\MPLPlotter\tplot.py:238: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   this_axis.set_ylim(yrange)
#
# 11-Jun-23 20:38:12: C:\Users\sians\anaconda3\lib\site-packages\pytplot\MPLPlotter\tplot.py:238: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   this_axis.set_ylim(yrange)

# %%
options('J_e_lo__C3_PP_RAP', 'ylog', True)
options('J_e_hi__C3_PP_RAP', 'ylog', True)
pytplot.timebar(1441642020.0, thick=2, color='red')
tplot(['J_e_lo__C3_PP_RAP', 'J_e_hi__C3_PP_RAP' ])
# Out:
# 11-Jun-23 20:38:14: C:\Users\sians\anaconda3\lib\site-packages\pytplot\MPLPlotter\tplot.py:238: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   this_axis.set_ylim(yrange)
#
# 11-Jun-23 20:38:14: C:\Users\sians\anaconda3\lib\site-packages\pytplot\MPLPlotter\tplot.py:238: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   this_axis.set_ylim(yrange)

# %%
options('J_e_lo__C4_PP_RAP', 'ylog', True)
options('J_e_hi__C4_PP_RAP', 'ylog', True)
pytplot.timebar(1441642020.0, thick=2, color='red')
tplot(['J_e_lo__C4_PP_RAP', 'J_e_hi__C4_PP_RAP' ])
# Out:
# 11-Jun-23 20:38:16: C:\Users\sians\anaconda3\lib\site-packages\pytplot\MPLPlotter\tplot.py:238: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   this_axis.set_ylim(yrange)
#
# 11-Jun-23 20:38:16: C:\Users\sians\anaconda3\lib\site-packages\pytplot\MPLPlotter\tplot.py:238: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   this_axis.set_ylim(yrange)

# %%
# time_c1=pytplot.data_quants['J_e_hi__C1_PP_RAP'].coords['time'].values
# c1_hi=pytplot.data_quants['J_e_hi__C1_PP_RAP'].values

# %%
# time_new_c1=[]
# for i in range(0,len(time_c1)):
#     time_new_c1= np.append(time_new_c1, datetime.datetime.fromtimestamp(time_c1[i]))

# %%
# start_date = dt.datetime(2015, 9, 7, 14, 0, 0)
# end_date = dt.datetime(2015, 9, 7, 18, 0, 0)
# # plt.xlim(start_date, end_date)
# # plt.ylim([1e3, 1e7])
# # plt.ylim(10^2, 10^6)
# line_date = dt.datetime(2015, 9, 7, 16, 7, 0)
# plt.axvline(x= line_date, color='r')

# # Create a plot with a single y-axis
# fig, ax1 = plt.subplots()
# ax1.semilogy(time_new_c1, c1_hi)
# ax1.set_xlim(start_date, end_date)
# # ax1.set_ylim([1e3, 1e7])
# # ax1.axvline(x= line_date, color='r')

# # # Create a second x-axis and plot data on it
# # L=pytplot.data_quants['L'].values
# # ax2 = ax1.twiny()
# # ax2.plot(L)


# ax1.set_xlabel('Time')
# ax1.set_ylabel('Electron Flux > 30 KeV($cm^{-2}$$s^{-1}$$sr^{-1}$$eV^{-1}$)')

# # ax1.plot(time_new_c1,  data.y[:], label=['1.8 MeV' ,  '2.1 MeV',  '2.6 MeV',  '3.4 MeV',  '4.2 MeV', '5.2 MeV'])


# # Add a legend to the plot
# ax1.legend()

# %%
..
# Out:
#   Input In [17]
#     ..
#     ^
# SyntaxError: invalid syntax
